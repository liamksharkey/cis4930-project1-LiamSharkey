# %%
import numpy as np
import pandas as pd
print(pd.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 2
#       1 import numpy as np
# ----> 2 import pd as pandas
#       3 print(pd.__version__)
#
# ModuleNotFoundError: No module named 'pd'
